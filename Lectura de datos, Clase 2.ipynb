# %% [markdown]
# # Lectura de datos

# %%
import pandas as pd 
import numpy as np

# %%
# %ls
# Out:
#  00_00_binder.ipynb                     02_02_basic_math.ipynb
#  00_00_primer_pasos.ipynb              'Clase 1.ipynb'
#  01_01_data_types.ipynb                 datasets/
#  01_02_read_iloc_unique_groupby.ipynb  'Lectura de datos, Clase 2.ipynb'
#  02_00_data_wrangling.ipynb             README.md
#  02_01_null_display.ipynb               requirements.txt

# %%
# %ls datasets
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# 12  13   25      F            1       Y             1   65.00      64.5
# 13  14   23      F            1       N             0   61.50      57.5
# 14  15   31      M            2       Y             1   73.00      74.0
# 15  16   26      M            2       Y             1   71.00      72.0
# 16  17   26      F            1       N             0   61.50      59.5
# 17  18   27      M            2       N             0   66.00      66.0
# 18  19   23      M            2       Y             1   70.00      69.0
# 19  20   24      F            1       Y             1   68.00      66.0
# 20  21   23      M            2       Y             1   69.00      67.0
# 21  22   29      M            2       N             0   71.00      70.0
# 22  23   25      M            2       N             0   70.00      68.0
# 23  24   26      M            2       N             0   69.00      71.0
# 24  25   23      F            1       Y             1   65.00      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 0           79        Y              1      7
# 1           70        Y              1      8
# 2           85        Y              1      7
# 3           87        Y              1     10
# 4           72        N              0      4
# 5           81        N              0      3
# 6          107        Y              1     10
# 7           98        Y              1      9
# 8          106        N              0      5
# 9           65        Y              1      8
# 10          96        Y              1      6
# 11          79        Y              1     10
# 12          92        Y              1      6
# 13          66        Y              1      4
# 14          72        Y              1      9
# 15         115        Y              1      6
# 16          90        N              0     10
# 17          74        Y              1      5
# 18          64        Y              1      3
# 19          85        Y              1      8
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
x = df.columns
x
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
type (x)
# Out:
# pandas.core.indexes.base.Index

# %%
y = list(x)
y
type(y)
# Out:
# list

# %%
y.sort()
y
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %% [markdown]
# # uso de 'for' para leer nombres de las columnas

# %%
for iterador in df.columns:
    print(iterador)
# Out:
# ID
# Age
# Gender
# GenderGroup
# Glasses
# GlassesGroup
# Height
# Wingspan
# CWDistance
# Complete
# CompleteGroup
# Score

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df['Age'].head(2)
# Out:
# 0    56
# 1    26
# Name: Age, dtype: int64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df[['Age']].head(2)
type(df[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Age', 'Gender','GenderGroup']].head(2)
# Out:
#    Age Gender  GenderGroup
# 0   56      F            1
# 1   26      F            1

# %% [markdown]
# ### loc y iloc
# [row.inicial:row final, col inicial:final]
#
# si usa loc, usa nombres de los renglones y nombres de las columnas
#
# si usa iloc, usa indices de los renglones y las columnas

# %%
df.iloc[2:10, 3:6]
# Out:
#    GenderGroup Glasses  GlassesGroup
# 2            1       Y             1
# 3            1       N             0
# 4            2       N             0
# 5            2       N             0
# 6            2       N             0
# 7            1       N             0
# 8            2       Y             1
# 9            1       Y             1

# %%
df.loc[2:7,'Age':'Height'] #si incluye todos
# Out:
#    Age Gender  GenderGroup Glasses  GlassesGroup  Height
# 2   33      F            1       Y             1    66.0
# 3   39      F            1       N             0    64.0
# 4   27      M            2       N             0    73.0
# 5   24      M            2       N             0    75.0
# 6   28      M            2       N             0    75.0
# 7   22      F            1       N             0    65.0

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df[['Complete', 'CompleteGroup','Score']]
# Out:
#    Complete  CompleteGroup  Score
# 0         Y              1      7
# 1         Y              1      8
# 2         Y              1      7
# 3         Y              1     10
# 4         N              0      4
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6
# 11        Y              1     10
# 12        Y              1      6
# 13        Y              1      4
# 14        Y              1      9
# 15        Y              1      6
# 16        N              0     10
# 17        Y              1      5
# 18        Y              1      3
# 19        Y              1      8
# 20        N              0      2
# 21        Y              1      8
# 22        Y              1      4
# 23        Y              1      5
# 24        N              0      3

# %%
df.iloc[:,-3:]
# Out:
#    Complete  CompleteGroup  Score
# 0         Y              1      7
# 1         Y              1      8
# 2         Y              1      7
# 3         Y              1     10
# 4         N              0      4
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6
# 11        Y              1     10
# 12        Y              1      6
# 13        Y              1      4
# 14        Y              1      9
# 15        Y              1      6
# 16        N              0     10
# 17        Y              1      5
# 18        Y              1      3
# 19        Y              1      8
# 20        N              0      2
# 21        Y              1      8
# 22        Y              1      4
# 23        Y              1      5
# 24        N              0      3

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.Gender.unique() #te dice lo que existe en esa columna
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.groupby(['Gender']).size() #te agrupa dependiendo de la columna
# Out:
# Gender
# F    12
# M    13
# dtype: int64
