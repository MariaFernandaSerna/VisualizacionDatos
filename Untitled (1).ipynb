# %% [markdown]
# # A7: visualización de datos multivariantes

# %%
# %ls datasets/
# Out:
#  adult.csv                     Canada.xlsx         mic.xlsx
#  airline_data.csv              Cartwheeldata.csv   movies.csv
#  antropometria00.csv           census.csv          nhanes_2015_2016.csv
#  antropometria-dataset-1.csv   coches.csv          pokemon.csv
#  antropometria-dataset.csv     cwurData.csv        sample_pivot.csv
# 'base de datos 2.csv'          data.csv            tips.csv
# 'base de datos.xlsx'           headbrain.csv       weight-height.csv
#  Book3.csv                     mic2.xlsx

# %%
import pandas as pd 
import numpy as np

# %%
#pip install plotly openpyxl xlrd

# %%
#pip install seaborn

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('datasets/antropometria-dataset-1.csv')
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
sns.displot(df['sistol'],
            bins=15)

# %%
sns.lmplot(x = 'sistol',
y = 'cintura', hue = 'sexo', data = df)

# %%
my_pivot=pd.pivot_table(df,
                        index = 'folio',
                        values='cintura',
                        columns = 'sexo'
                       )
my_pivot
# Out:
# sexo        1      2
# folio
# 10001    82.1    NaN
# 10011    78.4    NaN
# 10015   111.0    NaN
# 10021     NaN   73.1
# 10034     NaN   71.9
# ...       ...    ...
# 321838   69.8    NaN
# 321844    NaN   83.6
# 321849  105.0    NaN
# 321857    NaN  111.8
# 321861    NaN   84.3
#
# [17979 rows x 2 columns]

# %%
sns.displot(my_pivot.loc[:,[1]],
            )

# %%
sns.boxplot(data=my_pivot.loc[:,[2]],orient='h')

# %%
my_pivot2=pd.pivot_table(df,
                        index = 'folio',
                        values= ['sistol', 'diastol'],
                        columns = 'sexo'
                       )
my_pivot2
# Out:
#        diastol       sistol
# sexo         1     2      1      2
# folio
# 10001     78.0   NaN  125.0    NaN
# 10011     75.0   NaN  111.5    NaN
# 10015     80.0   NaN  111.0    NaN
# 10021      NaN  60.0    NaN  100.0
# 10034      NaN  64.5    NaN  104.5
# ...        ...   ...    ...    ...
# 321843     NaN  65.0    NaN  107.0
# 321844     NaN  60.0    NaN  118.0
# 321849    70.0   NaN  110.0    NaN
# 321857     NaN  50.0    NaN  120.0
# 321861     NaN  63.0    NaN  104.0
#
# [18585 rows x 4 columns]

# %%
sns.lmplot(x = my_pivot1.loc(:,[1]),
y = 'cintura', hue = 'sexo', data = df)
# Out:
#   File "/tmp/ipykernel_125/130510250.py", line 1
#     sns.lmplot(x = my_pivot1.loc(:,[1]),
#                                  ^
# SyntaxError: invalid syntax
