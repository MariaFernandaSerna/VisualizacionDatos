# %% [markdown]
# ## Clase 1 - Introduccion a Python

# %%
print('hola'
# Out:
#   File "/tmp/ipykernel_100/4054794001.py", line 1
#     print('hola'
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
print('hola')
# Out:
# hola

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.10681531, 0.4229275 , 0.7944445 , 0.48892979, 0.78859877,
#        0.65665526, 0.99574614, 0.35397822, 0.34582983, 0.34108549,
#        0.79369747, 0.98580363, 0.6881506 , 0.85376055, 0.35956866,
#        0.75778232, 0.29795593, 0.30596641, 0.80330961, 0.10794625,
#        0.43975161, 0.74685794, 0.79146883, 0.71857852, 0.59231048,
#        0.873753  , 0.49449018, 0.70427613, 0.31769318, 0.74073771,
#        0.81576408, 0.33708673, 0.80262972, 0.56750267, 0.16836183,
#        0.52697129, 0.58944159, 0.82434793, 0.95913722, 0.05628291,
#        0.21411361, 0.22460369, 0.82100538, 0.68238985, 0.50737538,
#        0.42047401, 0.58747314, 0.05965028, 0.0503978 , 0.29878481])

# %% [markdown]
# # Tipos de los datos

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre 1'
x
# Out:
# 'nombre 1'

# %%
type(x)
# Out:
# str

# %%
number = [1,2,3,4,5]
number
# Out:
# [1, 2, 3, 4, 5]

# %%
type(number)
# Out:
# list

# %%
number[0]
# Out:
# 1

# %%
sum_number = sum(number)
sum_number
# Out:
# 15

# %%
len(number)
# Out:
# 5
